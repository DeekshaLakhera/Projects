# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df.head()
# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  NaN
# 1         2    Australia    Sri Lanka   0.2     0                0  NaN
# 2         2    Australia    Sri Lanka   0.3     1                0  NaN
# 3         2    Australia    Sri Lanka   0.4     2                0  NaN
# 4         2    Australia    Sri Lanka   0.5     0                0  NaN
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %% [raw]
# - cities have 8548 null values
# - solution : We have venue column and the first word in every venue value define or tell the city name
# we can extract first word and replace it into city

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True) # now we don't need venue column

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %% [raw]
# we use only those cities where matches are played more than 600 times

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %% [raw]
# Current_score

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score
# 0              0
# 1              0
# 2              1
# 3              3
# 4              3

# %% [raw]
# over - total palyed over
# ball - ball number

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over ball_no
# 0              0    0       1
# 1              0    0       2
# 2              1    0       3
# 3              3    0       4
# 4              3    0       5

# %% [raw]
# Total bowled balls = over*6 + ball_no

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over ball_no  balls_bowled
# 0              0    0       1             1
# 1              0    0       2             2
# 2              1    0       3             3
# 3              3    0       4             4
# 4              3    0       5             5

# %% [raw]
# Total left balls = 120 - bowled_ball   (120 = 20 over)
# Note - there can be extra balls. total bowls can exceed 120

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over ball_no  balls_bowled  balls_left
# 0              0    0       1             1         119
# 1              0    0       2             2         118
# 2              1    0       3             3         117
# 3              3    0       4             4         116
# 4              3    0       5             5         115

# %% [raw]
# Wicket_left

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0       1             1         119
# 1  Melbourne              0    0       2             2         118
# 2  Melbourne              1    0       3             3         117
# 3  Melbourne              3    0       4             4         116
# 4  Melbourne              3    0       5             5         115
#
#    wickets_left
# 0            10
# 1            10
# 2            10
# 3            10
# 4            10

# %% [raw]
# current run rate(crr)

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0       1             1         119
# 1  Melbourne              0    0       2             2         118
# 2  Melbourne              1    0       3             3         117
# 3  Melbourne              3    0       4             4         116
# 4  Melbourne              3    0       5             5         115
#
#    wickets_left  crr
# 0            10  0.0
# 1            10  0.0
# 2            10  2.0
# 3            10  4.5
# 4            10  3.6

# %% [raw]
# runs in last 5 over

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist()) # 5 over = 30 balls

# %%
df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %% [markdown]
# ### Final Dataset

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team          city  current_score  balls_left  \
# 38208    Sri Lanka     Pakistan         Dubai            132           7
# 17954        India     Pakistan  Johannesburg             52          70
#
#        wickets_left      crr  last_five  runs_x
# 38208             6  7.00885       46.0     145
# 17954             8  6.24000       23.0     157

# %% [markdown]
# ### Model Buiding

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9882510314310058
# 1.6554128176952845
